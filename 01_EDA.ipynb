# %% [markdown]
# # Exploratory data analysis
# These are most certainly useful but there's some extra tools we can use.
#
# - `skimr` produces a more useful version of `summary()`
# - `DataExplorer` gives us a data profile report in a single line of code!

# %%
install.packages(c("skimr", "naniar", "DataExplorer", "visdat", "UpSetR"))
library(tidyverse)
heroes = read_csv("data/heroes_information.csv")
# Out:
# Installing packages into ‘/home/nbuser/R’
# (as ‘lib’ is unspecified)
# also installing the dependencies ‘rlang’, ‘tinytex’, ‘tidyselect’, ‘data.table’, ‘rmarkdown’, ‘networkD3’
# Error: package or namespace load failed for ‘tidyverse’ in library.dynam(lib, package, package.lib):
#  shared object ‘readxl.so’ not found
# Traceback:
#
# 1. library(tidyverse)
# 2. tryCatch({
#  .     attr(package, "LibPath") <- which.lib.loc
#  .     ns <- loadNamespace(package, lib.loc)
#  .     env <- attachNamespace(ns, pos = pos, deps)
#  . }, error = function(e) {
#  .     P <- if (!is.null(cc <- conditionCall(e)))
#  .         paste(" in", deparse(cc)[1L])
#  .     else ""
#  .     msg <- gettextf("package or namespace load failed for %s%s:\n %s",
#  .         sQuote(package), P, conditionMessage(e))
#  .     if (logical.return)
#  .         message(paste("Error:", msg), domain = NA)
#  .     else stop(msg, call. = FALSE, domain = NA)
#  . })
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. value[[3L]](cond)
# 6. stop(msg, call. = FALSE, domain = NA)

# %% [markdown]
# ## Data profiling
# `skimr` is a great way to improve upon the `summary()` function.

# %%
library(skimr)
print(skim(heroes))
# Out:
# Attaching package: ‘skimr’
#
# The following objects are masked from ‘package:dplyr’:
#
#     contains, ends_with, everything, matches, num_range, one_of,
#     starts_with
# Skim summary statistics
#  n obs: 734
#  n variables: 11
#
# ── Variable type:character ─────────────────────────────────────────────────────
#    variable missing complete   n min max empty n_unique
#   Alignment       0      734 734   1   7     0        4
#   Eye color       0      734 734   1  23     0       23
#      Gender       0      734 734   1   6     0        3
#  Hair color       0      734 734   1  16     0       30
#        name       0      734 734   1  25     0      715
#   Publisher      15      719 734   4  17     0       24
#        Race       0      734 734   1  18     0       62
#  Skin color       0      734 734   1  14     0       17
#
# ── Variable type:integer ───────────────────────────────────────────────────────
#  variable missing complete   n  mean     sd p0    p25   p50    p75 p100
#        X1       0      734 734 366.5 212.03  0 183.25 366.5 549.75  733
#      hist
#  ▇▇▇▇▇▇▇▇
#
# ── Variable type:numeric ───────────────────────────────────────────────────────
#  variable missing complete   n   mean     sd  p0 p25 p50 p75 p100     hist
#    Height       0      734 734 102.25 139.62 -99 -99 175 185  975 ▅▂▇▁▁▁▁▁
#    Weight       2      732 734  43.86 130.82 -99 -99  62  90  900 ▅▇▁▁▁▁▁▁

# %% [markdown]
# It also has a data.frame behind the scenes so we can do a lot of other things than just see the results

# %%
skim(heroes)
# Out:
#     variable   type      stat     level value     formatted
# 1   X1         integer   missing  .all    0.0000  0
# 2   X1         integer   complete .all  734.0000  734
# 3   X1         integer   n        .all  734.0000  734
# 4   X1         integer   mean     .all  366.5000  366.5
# 5   X1         integer   sd       .all  212.0318  212.03
# 6   X1         integer   p0       .all    0.0000  0
# 7   X1         integer   p25      .all  183.2500  183.25
# 8   X1         integer   p50      .all  366.5000  366.5
# 9   X1         integer   p75      .all  549.7500  549.75
# 10  X1         integer   p100     .all  733.0000  733
# 11  X1         integer   hist     .all        NA  ▇▇▇▇▇▇▇▇
# 12  name       character missing  .all    0.0000  0
# 13  name       character complete .all  734.0000  734
# 14  name       character n        .all  734.0000  734
# 15  name       character min      .all    1.0000  1
# 16  name       character max      .all   25.0000  25
# 17  name       character empty    .all    0.0000  0
# 18  name       character n_unique .all  715.0000  715
# 19  Gender     character missing  .all    0.0000  0
# 20  Gender     character complete .all  734.0000  734
# 21  Gender     character n        .all  734.0000  734
# 22  Gender     character min      .all    1.0000  1
# 23  Gender     character max      .all    6.0000  6
# 24  Gender     character empty    .all    0.0000  0
# 25  Gender     character n_unique .all    3.0000  3
# 26  Eye color  character missing  .all    0.0000  0
# 27  Eye color  character complete .all  734.0000  734
# 28  Eye color  character n        .all  734.0000  734
# 29  Eye color  character min      .all    1.0000  1
# 30  Eye color  character max      .all   23.0000  23
# ... ...        ...       ...      ...   ...       ...
# 60  Publisher  character n        .all  734.00000 734
# 61  Publisher  character min      .all    4.00000 4
# 62  Publisher  character max      .all   17.00000 17
# 63  Publisher  character empty    .all    0.00000 0
# 64  Publisher  character n_unique .all   24.00000 24
# 65  Skin color character missing  .all    0.00000 0
# 66  Skin color character complete .all  734.00000 734
# 67  Skin color character n        .all  734.00000 734
# 68  Skin color character min      .all    1.00000 1
# 69  Skin color character max      .all   14.00000 14
# 70  Skin color character empty    .all    0.00000 0
# 71  Skin color character n_unique .all   17.00000 17
# 72  Alignment  character missing  .all    0.00000 0
# 73  Alignment  character complete .all  734.00000 734
# 74  Alignment  character n        .all  734.00000 734
# 75  Alignment  character min      .all    1.00000 1
# 76  Alignment  character max      .all    7.00000 7
# 77  Alignment  character empty    .all    0.00000 0
# 78  Alignment  character n_unique .all    4.00000 4
# 79  Weight     numeric   missing  .all    2.00000 2
# 80  Weight     numeric   complete .all  732.00000 732
# 81  Weight     numeric   n        .all  734.00000 734
# 82  Weight     numeric   mean     .all   43.85519 43.86
# 83  Weight     numeric   sd       .all  130.82373 130.82
# 84  Weight     numeric   p0       .all  -99.00000 -99
# 85  Weight     numeric   p25      .all  -99.00000 -99
# 86  Weight     numeric   p50      .all   62.00000 62
# 87  Weight     numeric   p75      .all   90.00000 90
# 88  Weight     numeric   p100     .all  900.00000 900
# 89  Weight     numeric   hist     .all         NA ▅▇▁▁▁▁▁▁

# %% [markdown]
# The `visdat` and `naniar` packages are great for getting some visualisations about the data, particularly missing values. `naniar` makes use of `UpSetR` for great effect in looking for overlaps in missings - really useful for instance when you get survey data for seeing which questions are part of conditional branches!

# %%
library(visdat)
vis_dat(heroes)
# Out:
# Error in library(visdat): there is no package called ‘visdat’
# Traceback:
#
# 1. library(visdat)
# 2. stop(txt, domain = NA)

# %%
library(naniar)
library(UpSetR)

heroes %>%
  as_shadow_upset() %>%
  upset()

# %% [markdown]
# These help with visual and ad-hoc explorations. A nifty, quick way of getting a profile of ad ataset is with the `DataExplorer` package.

# %%
library(DataExplorer)
create_report(heroes, output_file="heroes.html", output_dir="outputs")
# Out:
# processing file: report.rmd
#   |..                                                               |   3%
#   ordinary text without R code
#
#   |....                                                             |   6%
# label: global_options (with options)
# List of 1
#  $ include: logi FALSE
#
#   |......                                                           |   9%
#   ordinary text without R code
#
#   |........                                                         |  12%
# label: basic_statistics
#   |..........                                                       |  15%
#   ordinary text without R code
#
#   |...........                                                      |  18%
# label: data_structure
#   |.............                                                    |  21%
#   ordinary text without R code
#
#   |...............                                                  |  24%
# label: missing_profile
#   |.................                                                |  26%
#   ordinary text without R code
#
#   |...................                                              |  29%
# label: univariate_distribution_header
#   |.....................                                            |  32%
#   ordinary text without R code
#
#   |.......................                                          |  35%
# label: plot_histogram
#   |.........................                                        |  38%
#   ordinary text without R code
#
#   |...........................                                      |  41%
# label: plot_density
#   |.............................                                    |  44%
#   ordinary text without R code
#
#   |...............................                                  |  47%
# label: plot_frequency_bar
#   |................................                                 |  50%
#   ordinary text without R code
#
#   |..................................                               |  53%
# label: plot_response_bar
#   |....................................                             |  56%
#   ordinary text without R code
#
#   |......................................                           |  59%
# label: plot_with_bar
#   |........................................                         |  62%
#   ordinary text without R code
#
#   |..........................................                       |  65%
# label: correlation_analysis
#   |............................................                     |  68%
#   ordinary text without R code
#
#   |..............................................                   |  71%
# label: principle_component_analysis
#   |................................................                 |  74%
#   ordinary text without R code
#
#   |..................................................               |  76%
# label: bivariate_distribution_header
#   |....................................................             |  79%
#   ordinary text without R code
#
#   |......................................................           |  82%
# label: plot_response_boxplot
#   |.......................................................          |  85%
#   ordinary text without R code
#
#   |.........................................................        |  88%
# label: plot_by_boxplot
#   |...........................................................      |  91%
#   ordinary text without R code
#
#   |.............................................................    |  94%
# label: plot_response_scatterplot
#   |...............................................................  |  97%
#   ordinary text without R code
#
#   |.................................................................| 100%
# label: plot_by_scatterplot
# output file: /home/nbuser/library/outputs/report.knit.md
# /usr/bin/pandoc +RTS -K512m -RTS /home/nbuser/library/outputs/report.utf8.md --to html4 --from markdown+autolink_bare_uris+ascii_identifiers+tex_math_single_backslash --output /home/nbuser/library/outputs/heroes.html --smart --email-obfuscation none --self-contained --standalone --section-divs --table-of-contents --toc-depth 6 --template /home/nbuser/R/rmarkdown/rmd/h/default.html --no-highlight --variable highlightjs=1 --variable 'theme:cerulean' --include-in-header /tmp/RtmpeYceKn/rmarkdown-str245414e3ef1.html --mathjax --variable 'mathjax-url:https://mathjax.rstudio.com/latest/MathJax.js?config=TeX-AMS-MML_HTMLorMML'
# Output created: outputs/heroes.html
#
#
# Report is generated at "outputs/heroes.html".

# %% [markdown]
# > Check out the report produced by DataExplorer then explore the powers dataset (`data/super_hero_powers.csv`) with the tools we've used here
