# %% [markdown]
# # Feature Engineering
# We need to clean up columns, add new ones, handle missings and so forth. Some of this can/should be done post-sampling to avoid leaking information about the test data into our models inadvertently.

# %%
install.packages(c("tidyverse","naniar","ggthemes"))
library(tidyverse)
library(naniar)
heroes = read_csv("data/heroes_information.csv")
powers = read_csv("data/super_hero_powers.csv")
# Out:
# Installing packages into ‘/home/nbuser/R’
# (as ‘lib’ is unspecified)
# Warning message in install.packages(c("tidyverse", "naniar", "ggthemes")):
# “installation of package ‘tidyverse’ had non-zero exit status”
# Error: package or namespace load failed for ‘tidyverse’ in library.dynam(lib, package, package.lib):
#  shared object ‘readxl.so’ not found
# Traceback:
#
# 1. library(tidyverse)
# 2. tryCatch({
#  .     attr(package, "LibPath") <- which.lib.loc
#  .     ns <- loadNamespace(package, lib.loc)
#  .     env <- attachNamespace(ns, pos = pos, deps)
#  . }, error = function(e) {
#  .     P <- if (!is.null(cc <- conditionCall(e)))
#  .         paste(" in", deparse(cc)[1L])
#  .     else ""
#  .     msg <- gettextf("package or namespace load failed for %s%s:\n %s",
#  .         sQuote(package), P, conditionMessage(e))
#  .     if (logical.return)
#  .         message(paste("Error:", msg), domain = NA)
#  .     else stop(msg, call. = FALSE, domain = NA)
#  . })
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. value[[3L]](cond)
# 6. stop(msg, call. = FALSE, domain = NA)

# %% [markdown]
# ## Cleaning data
# We can use packages like `forcats`, `stringr`, and `lubridate` to fix values. Using `dplyr` we're able to programmatically fix issues across multiple columns.

# %%
replaceLT0 = function(x) ifelse(x < 0, NA, x) 
# mutate_if takes a dataset, applies a condition to each column, and for each column that returned TRUE applies a function to it
heroes = mutate_if(heroes, is.numeric, replaceLT0)
gg_miss_var(heroes) + ggthemes::theme_few()

# %% [markdown]
# > Write a cleaning statement that converts missings encoded as hyphens to NA

# %% [markdown]
# For rebasing factors, handling typos etc. we can use the `forcats` package.
#
# - `fct_explicit_na` converts missings into a distinct level. This can be very handy for modelling observations with missings, as there could be some systemic reason for the missings that has predictive value for your model
# - `fct_infreq` reorders a factor so the most common level is first
# - `fct_lump` consolidates low frequency levels into a single level
# - `fct_relabel` applies a function to level labels to do things like remove special characters
#
# ![](http://perso.ens-lyon.fr/lise.vaudor/Rfigures/forcats/forcats.png)

# %%
heroes = mutate_if(heroes, is.character, fct_explicit_na)
gg_miss_var(heroes) + ggthemes::theme_few()
# Out:
# Error in gg_miss_var(heroes): could not find function "gg_miss_var"
# Traceback:

# %%
fct_count(heroes$Alignment)
fct_count(fct_infreq(heroes$Alignment))
fct_count(fct_lump(heroes$Race, 3))
# Out:
#   f       n
# 1 -         7
# 2 bad     207
# 3 good    496
# 4 neutral  24
#   f       n
# 1 good    496
# 2 bad     207
# 3 neutral  24
# 4 -         7
#   f      n
# 1 -      304
# 2 Human  208
# 3 Mutant  63
# 4 Other  159

# %% [markdown]
# ## Lags
# Lagged values are past values brought forward for use as predictive variables. These might be things like the previous payment amount, time spent playing previously etc.
#
# `lag()` (and `lead()` although it tends to be less relevant whilst building models) returns a previous row's value onto the current row.
#
# ```{r}
# lag(1:5)
# ```
#
# Use lags to provide prior values, like position 6 months ago:
# ```{r}
# lag(1:50, n = 6, default = 0)
# ```
#
# Use lags to flag if values changed
# ```{r}
# x=rep(c(2,1,1,2),2)
# x==lag(x)
# ```
#
# Use lags to determine change
# ```{r}
# x=1:15
# (x/lag(x))-1
# ```
#
#
# ## Aggregates
# Producing aggregate measures like lifetime value, typical profitability, max months in arrears in the past year, times seen etc are useful measures.
#
# It is worth noting though that if you make aggregates of historic data and use these in a model, going forward you will need those levels of historic data to make predictions.
#
# Find the rolling mean /  max / min / etc... over previous values:
# ```{r}
# library(RcppRoll)
# iris %>%
#   group_by(Species) %>%
#   mutate(rollMean=roll_meanr(lag(Sepal.Width),
#                              n = 5))%>%
#   head()
# ```
#
# Find the min / max / sum / etc... in all prior observations:
# ```{r}
# iris %>%
#   group_by(Species) %>%
#   mutate(smallest=cummin(Sepal.Width))%>%
#   head()
# ```

# %% [markdown]
# > Use the `mutate()` function to work out the difference for each hero in weight against the mean for their race

# %% [markdown]
# ## Extra data
# We can also gain additional features by joining data. [Lise Vidaur](http://perso.ens-lyon.fr/lise.vaudor) has some nifty viz (as een above re: forcats!) for joins.

# %%
left_join(heroes, powers, by=c("name"="hero_names"))
# Out:
# Warning message:
# “Column `name`/`hero_names` joining factor and character vector, coercing into character vector”
#     X1  name              Gender Eye color Race              Hair color
# 1    0  A-Bomb            Male   yellow    Human             No Hair
# 2    1  Abe Sapien        Male   blue      Icthyo Sapien     No Hair
# 3    2  Abin Sur          Male   blue      Ungaran           No Hair
# 4    3  Abomination       Male   green     Human / Radiation No Hair
# 5    4  Abraxas           Male   blue      Cosmic Entity     Black
# 6    5  Absorbing Man     Male   blue      Human             No Hair
# 7    6  Adam Monroe       Male   blue      -                 Blond
# 8    7  Adam Strange      Male   blue      Human             Blond
# 9    8  Agent 13          Female blue      -                 Blond
# 10   9  Agent Bob         Male   brown     Human             Brown
# 11  10  Agent Zero        Male   -         -                 -
# 12  11  Air-Walker        Male   blue      -                 White
# 13  12  Ajax              Male   brown     Cyborg            Black
# 14  13  Alan Scott        Male   blue      -                 Blond
# 15  14  Alex Mercer       Male   -         Human             -
# 16  15  Alex Woolsly      Male   -         -                 -
# 17  16  Alfred Pennyworth Male   blue      Human             Black
# 18  17  Alien             Male   -         Xenomorph XX121   No Hair
# 19  18  Allan Quatermain  Male   -         -                 -
# 20  19  Amazo             Male   red       Android           -
# 21  20  Ammo              Male   brown     Human             Black
# 22  21  Ando Masahashi    Male   -         -                 -
# 23  22  Angel             Male   blue      -                 Blond
# 24  23  Angel             Male   -         Vampire           -
# 25  24  Angel Dust        Female yellow    Mutant            Black
# 26  25  Angel Salvadore   Female brown     -                 Black
# 27  26  Angela            Female -         -                 -
# 28  27  Animal Man        Male   blue      Human             Blond
# 29  28  Annihilus         Male   green     -                 No Hair
# 30  29  Ant-Man           Male   blue      Human             Blond
# ... ... ...               ...    ...       ...               ...
# 705 704 Walrus            Male   blue      Human             Black
# 706 705 War Machine       Male   brown     Human             Brown
# 707 706 Warbird           Female blue      -                 Blond
# 708 707 Warlock           Male   red       -                 Blond
# 709 708 Warp              Male   brown     -                 Black
# 710 709 Warpath           Male   brown     Mutant            Black
# 711 710 Wasp              Female blue      Human             Auburn
# 712 711 Watcher           Male   -         -                 -
# 713 712 Weapon XI         Male   -         -                 -
# 714 713 White Canary      Female brown     Human             Black
# 715 714 White Queen       Female blue      -                 Blond
# 716 715 Wildfire          Male   -         -                 -
# 717 716 Winter Soldier    Male   brown     Human             Brown
# 718 717 Wiz Kid           -      brown     -                 Black
# 719 718 Wolfsbane         Female green     -                 Auburn
# 720 719 Wolverine         Male   blue      Mutant            Black
# 721 720 Wonder Girl       Female blue      Demi-God          Blond
# 722 721 Wonder Man        Male   red       -                 Black
# 723 722 Wonder Woman      Female blue      Amazon            Black
# 724 723 Wondra            Female -         -                 -
# 725 724 Wyatt Wingfoot    Male   brown     -                 Black
# 726 725 X-23              Female green     Mutant / Clone    Black
# 727 726 X-Man             Male   blue      -                 Brown
# 728 727 Yellow Claw       Male   blue      -                 No Hair
# 729 728 Yellowjacket      Male   blue      Human             Blond
# 730 729 Yellowjacket II   Female blue      Human             Strawberry Blond
# 731 730 Ymir              Male   white     Frost Giant       No Hair
# 732 731 Yoda              Male   brown     Yoda's species    White
# 733 732 Zatanna           Female blue      Human             Black
# 734 733 Zoom              Male   red       -                 Brown
#     Height Publisher         Skin color Alignment ... Web Creation
# 1   203    Marvel Comics     -          good      ... False
# 2   191    Dark Horse Comics blue       good      ... False
# 3   185    DC Comics         red        good      ... False
# 4   203    Marvel Comics     -          bad       ... False
# 5   -99    Marvel Comics     -          bad       ... False
# 6   193    Marvel Comics     -          bad       ... False
# 7   -99    NBC - Heroes      -          good      ... False
# 8   185    DC Comics         -          good      ... False
# 9   173    Marvel Comics     -          good      ... NA
# 10  178    Marvel Comics     -          good      ... False
# 11  191    Marvel Comics     -          good      ... False
# 12  188    Marvel Comics     -          bad       ... False
# 13  193    Marvel Comics     -          bad       ... False
# 14  180    DC Comics         -          good      ... False
# 15  -99    Wildstorm         -          bad       ... False
# 16  -99    NBC - Heroes      -          good      ... False
# 17  178    DC Comics         -          good      ... NA
# 18  244    Dark Horse Comics black      bad       ... False
# 19  -99    Wildstorm         -          good      ... False
# 20  257    DC Comics         -          bad       ... False
# 21  188    Marvel Comics     -          bad       ... False
# 22  -99    NBC - Heroes      -          good      ... False
# 23  183    Marvel Comics     -          good      ... False
# 24  -99    Dark Horse Comics -          good      ... False
# 25  165    Marvel Comics     -          good      ... False
# 26  163    Marvel Comics     -          good      ... False
# 27  -99    Image Comics      -          bad       ... False
# 28  183    DC Comics         -          good      ... False
# 29  180    Marvel Comics     -          bad       ... False
# 30  211    Marvel Comics     -          good      ... False
# ... ...    ...               ...        ...           ...
# 705 183.0  Marvel Comics     -          bad       ... False
# 706 185.0  Marvel Comics     -          good      ... False
# 707 180.0  Marvel Comics     -          good      ... NA
# 708 188.0  Marvel Comics     -          good      ... False
# 709 173.0  DC Comics         -          bad       ... False
# 710 218.0  Marvel Comics     -          good      ... False
# 711 163.0  Marvel Comics     -          good      ... False
# 712 -99.0  Marvel Comics     -          good      ... False
# 713 -99.0  Marvel Comics     -          bad       ... False
# 714 -99.0  DC Comics         -          bad       ... False
# 715 178.0  Marvel Comics     -          good      ... NA
# 716 -99.0  DC Comics         -          good      ... False
# 717 175.0  Marvel Comics     -          good      ... False
# 718 140.0  Marvel Comics     -          good      ... NA
# 719 366.0  Marvel Comics     -          good      ... False
# 720 160.0  Marvel Comics     -          good      ... False
# 721 165.0  DC Comics         -          good      ... False
# 722 188.0  Marvel Comics     -          good      ... False
# 723 183.0  DC Comics         -          good      ... False
# 724 -99.0  Marvel Comics     -          good      ... NA
# 725 196.0  Marvel Comics     -          good      ... NA
# 726 155.0  Marvel Comics     -          good      ... False
# 727 175.0  Marvel Comics     -          good      ... False
# 728 188.0  Marvel Comics     -          bad       ... NA
# 729 183.0  Marvel Comics     -          good      ... False
# 730 165.0  Marvel Comics     -          good      ... False
# 731 304.8  Marvel Comics     white      good      ... False
# 732  66.0  George Lucas      green      good      ... False
# 733 170.0  DC Comics         -          good      ... False
# 734 185.0  DC Comics         -          bad       ... False
#     Reality Warping Odin Force Symbiote Costume Speed Force Phoenix Force
# 1   False           False      False            False       False
# 2   False           False      False            False       False
# 3   False           False      False            False       False
# 4   False           False      False            False       False
# 5   False           False      False            False       False
# 6   False           False      False            False       False
# 7   False           False      False            False       False
# 8   False           False      False            False       False
# 9   NA              NA         NA               NA          NA
# 10  False           False      False            False       False
# 11  False           False      False            False       False
# 12  False           False      False            False       False
# 13  False           False      False            False       False
# 14  False           False      False            False       False
# 15  False           False      False            False       False
# 16  False           False      False            False       False
# 17  NA              NA         NA               NA          NA
# 18  False           False      False            False       False
# 19  False           False      False            False       False
# 20  False           False      False            False       False
# 21  False           False      False            False       False
# 22  False           False      False            False       False
# 23  False           False      False            False       False
# 24  False           False      False            False       False
# 25  False           False      False            False       False
# 26  False           False      False            False       False
# 27  False           False      False            False       False
# 28  False           False      False            False       False
# 29  False           False      False            False       False
# 30  False           False      False            False       False
# ... ...             ...        ...              ...         ...
# 705 False           False      False            False       False
# 706 False           False      False            False       False
# 707 NA              NA         NA               NA          NA
# 708 False           False      False            False       False
# 709 False           False      False            False       False
# 710 False           False      False            False       False
# 711 False           False      False            False       False
# 712 False           False      False            False       False
# 713 False           False      False            False       False
# 714 False           False      False            False       False
# 715 NA              NA         NA               NA          NA
# 716 False           False      False            False       False
# 717 False           False      False            False       False
# 718 NA              NA         NA               NA          NA
# 719 False           False      False            False       False
# 720 False           False      False            False       False
# 721 False           False      False            False       False
# 722 False           False      False            False       False
# 723 False           False      False            False       False
# 724 NA              NA         NA               NA          NA
# 725 NA              NA         NA               NA          NA
# 726 False           False      False            False       False
# 727 False           False      False            False       False
# 728 NA              NA         NA               NA          NA
# 729 False           False      False            False       False
# 730 False           False      False            False       False
# 731 False           False      False            False       False
# 732 False           False      False            False       False
# 733 False           False      False            False       False
# 734 False           False      False            False       False
#     Molecular Dissipation Vision - Cryo Omnipresent Omniscient
# 1   False                 False         False       False
# 2   False                 False         False       False
# 3   False                 False         False       False
# 4   False                 False         False       False
# 5   False                 False         False       False
# 6   False                 False         False       False
# 7   False                 False         False       False
# 8   False                 False         False       False
# 9   NA                    NA            NA          NA
# 10  False                 False         False       False
# 11  False                 False         False       False
# 12  False                 False         False       False
# 13  False                 False         False       False
# 14  False                 False         False       False
# 15  False                 False         False       False
# 16  False                 False         False       False
# 17  NA                    NA            NA          NA
# 18  False                 False         False       False
# 19  False                 False         False       False
# 20  False                 False         False       False
# 21  False                 False         False       False
# 22  False                 False         False       False
# 23  False                 False         False       False
# 24  False                 False         False       False
# 25  False                 False         False       False
# 26  False                 False         False       False
# 27  False                 False         False       False
# 28  False                 False         False       False
# 29  False                 False         False       False
# 30  False                 False         False       False
# ... ...                   ...           ...         ...
# 705 False                 False         False       False
# 706 False                 False         False       False
# 707 NA                    NA            NA          NA
# 708 False                 False         False       False
# 709 False                 False         False       False
# 710 False                 False         False       False
# 711 False                 False         False       False
# 712 False                 False         False       False
# 713 False                 False         False       False
# 714 False                 False         False       False
# 715 NA                    NA            NA          NA
# 716 False                 False         False       False
# 717 False                 False         False       False
# 718 NA                    NA            NA          NA
# 719 False                 False         False       False
# 720 False                 False         False       False
# 721 False                 False         False       False
# 722 False                 False         False       False
# 723 False                 False         False       False
# 724 NA                    NA            NA          NA
# 725 NA                    NA            NA          NA
# 726 False                 False         False       False
# 727 False                 False         False       False
# 728 NA                    NA            NA          NA
# 729 False                 False         False       False
# 730 False                 False         False       False
# 731 False                 False         False       False
# 732 False                 False         False       False
# 733 False                 False         False       False
# 734 False                 False         False       False

# %% [markdown]
# ## Reshaping data
# We might also need to reshape data. This is usually what I think of as *unpivoting* my data or *pivoting* it due to my use of Excel.
#
# In R, the function for unpivoting data is `gather()`, like gathering all your data up, and the function for pivoting your data is `spread()`.
#
# `gather()` will need to know what the name should be for column containing our old headers, what the column name should be for the one holding our old cell values, and what columns we do/don't want to unpivot. `spread` will need to know which column is going to be used for headers, which one will become the cells.

# %%
powers_long = gather(powers, power, present, -hero_names)
str(powers_long)
# Out:
# Classes ‘tbl_df’, ‘tbl’ and 'data.frame':	111389 obs. of  3 variables:
#  $ hero_names: chr  "3-D Man" "A-Bomb" "Abe Sapien" "Abin Sur" ...
#  $ power     : chr  "Agility" "Agility" "Agility" "Agility" ...
#  $ present   : chr  "True" "False" "True" "False" ...

# %% [markdown]
# > Have a think about what might be needed to re-pivot the data (feel free to peek at the docs too!) and give it a go
